# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("crop_yield.csv")
df
# Out:
#                 Crop  Crop_Year       Season              State      Area  \
# 0           Arecanut       1997  Whole Year               Assam   73814.0
# 1          Arhar/Tur       1997  Kharif                   Assam    6637.0
# 2        Castor seed       1997  Kharif                   Assam     796.0
# 3           Coconut        1997  Whole Year               Assam   19656.0
# 4       Cotton(lint)       1997  Kharif                   Assam    1739.0
# ...              ...        ...          ...                ...       ...
# 19684  Small millets       1998  Kharif                Nagaland    4000.0
# 19685          Wheat       1998  Rabi                  Nagaland    1000.0
# 19686          Maize       1997  Kharif       Jammu and Kashmir  310883.0
# 19687           Rice       1997  Kharif       Jammu and Kashmir  275746.0
# 19688          Wheat       1997  Rabi         Jammu and Kashmir  239344.0
#
#        Production  Annual_Rainfall   Fertilizer  Pesticide        Yield
# ...

# %%
df.head()
# Out:
#            Crop  Crop_Year       Season  State     Area  Production  \
# 0      Arecanut       1997  Whole Year   Assam  73814.0       56708
# 1     Arhar/Tur       1997  Kharif       Assam   6637.0        4685
# 2   Castor seed       1997  Kharif       Assam    796.0          22
# 3      Coconut        1997  Whole Year   Assam  19656.0   126905000
# 4  Cotton(lint)       1997  Kharif       Assam   1739.0         794
#
#    Annual_Rainfall  Fertilizer  Pesticide        Yield
# 0           2051.4  7024878.38   22882.34     0.796087
# 1           2051.4   631643.29    2057.47     0.710435
# 2           2051.4    75755.32     246.76     0.238333
# 3           2051.4  1870661.52    6093.36  5238.051739
# 4           2051.4   165500.63     539.09     0.420909

# %% [markdown]
# ###Here are the explaination of each column
#
# Crop: This column likely contains the name or type of the crop that is being cultivated or harvested. For example, it could include names like wheat, rice, corn, soybeans, etc.
#
# Crop_Year: This column likely represents the year in which the crop was planted or harvested. It helps to track the timeline of agricultural activities for each specific crop.
#
# Season: This column likely represents the season in which the crop was grown or harvested. Seasons can include categories like "summer," "winter," "monsoon," etc., depending on the region.
#
# State: This column likely represents the state or geographical region where the crop was cultivated. It helps to provide information about the location of the agricultural activity.
#
# Area: This column likely represents the area of land in a specific unit (such as hectares or acres) where the crop was planted or harvested.
#
# Production: This column likely represents the quantity or amount of the harvested crop. It indicates how much of the crop was successfully grown and harvested.
#
# Annual_Rainfall: This column likely represents the amount of rainfall that occurred during the year in the specific region. Rainfall is an important factor in agricultural productivity as it affects crop growth.
#
# Fertilizer: This column likely represents information about the type or amount of fertilizers used during the cultivation of the crop. Fertilizers are used to enrich the soil with essential nutrients for plant growth.
#
# Pesticide: This column likely represents information about the type or amount of pesticides used to protect the crop from pests and diseases.
#
# Yield: This column likely represents the yield of the crop, which is the production amount divided by the cultivated area. It provides insight into the efficiency and productivity of the agricultural process.

# %%
df.tail()
# Out:
#                 Crop  Crop_Year       Season              State      Area  \
# 19684  Small millets       1998  Kharif                Nagaland    4000.0
# 19685          Wheat       1998  Rabi                  Nagaland    1000.0
# 19686          Maize       1997  Kharif       Jammu and Kashmir  310883.0
# 19687           Rice       1997  Kharif       Jammu and Kashmir  275746.0
# 19688          Wheat       1997  Rabi         Jammu and Kashmir  239344.0
#
#        Production  Annual_Rainfall   Fertilizer  Pesticide     Yield
# 19684        2000           1498.0    395200.00    1160.00  0.500000
# 19685        3000           1498.0     98800.00     290.00  3.000000
# 19686      440900           1356.2  29586735.11   96373.73  1.285000
# 19687        5488           1356.2  26242746.82   85481.26  0.016667
# 19688      392160           1356.2  22778368.48   74196.64  1.261818

# %%
df.describe()
# Out:
#           Crop_Year          Area    Production  Annual_Rainfall  \
# count  19689.000000  1.968900e+04  1.968900e+04     19689.000000
# mean    2009.127584  1.799266e+05  1.643594e+07      1437.755177
# std        6.498099  7.328287e+05  2.630568e+08       816.909589
# min     1997.000000  5.000000e-01  0.000000e+00       301.300000
# 25%     2004.000000  1.390000e+03  1.393000e+03       940.700000
# 50%     2010.000000  9.317000e+03  1.380400e+04      1247.600000
# 75%     2015.000000  7.511200e+04  1.227180e+05      1643.700000
# max     2020.000000  5.080810e+07  6.326000e+09      6552.700000
#
#          Fertilizer     Pesticide         Yield
# count  1.968900e+04  1.968900e+04  19689.000000
# mean   2.410331e+07  4.884835e+04     79.954009
# std    9.494600e+07  2.132874e+05    878.306193
# min    5.417000e+01  9.000000e-02      0.000000
# 25%    1.880146e+05  3.567000e+02      0.600000
# 50%    1.234957e+06  2.421900e+03      1.030000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19689 entries, 0 to 19688
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Crop             19689 non-null  object
#  1   Crop_Year        19689 non-null  int64
#  2   Season           19689 non-null  object
#  3   State            19689 non-null  object
#  4   Area             19689 non-null  float64
#  5   Production       19689 non-null  int64
#  6   Annual_Rainfall  19689 non-null  float64
#  7   Fertilizer       19689 non-null  float64
#  8   Pesticide        19689 non-null  float64
#  9   Yield            19689 non-null  float64
# dtypes: float64(5), int64(2), object(3)
# memory usage: 1.5+ MB

# %%
df.shape
# Out:
# (19689, 10)

# %%
df.dtypes
# Out:
# Crop                object
# Crop_Year            int64
# Season              object
# State               object
# Area               float64
# Production           int64
# Annual_Rainfall    float64
# Fertilizer         float64
# Pesticide          float64
# Yield              float64
# dtype: object

# %%
for i in df.columns:
    print(i,"         : ", df[i].unique())
# Out:
# Crop          :  ['Arecanut' 'Arhar/Tur' 'Castor seed' 'Coconut ' 'Cotton(lint)'
#  'Dry chillies' 'Gram' 'Jute' 'Linseed' 'Maize' 'Mesta' 'Niger seed'
#  'Onion' 'Other  Rabi pulses' 'Potato' 'Rapeseed &Mustard' 'Rice'
#  'Sesamum' 'Small millets' 'Sugarcane' 'Sweet potato' 'Tapioca' 'Tobacco'
#  'Turmeric' 'Wheat' 'Bajra' 'Black pepper' 'Cardamom' 'Coriander' 'Garlic'
#  'Ginger' 'Groundnut' 'Horse-gram' 'Jowar' 'Ragi' 'Cashewnut' 'Banana'
#  'Soyabean' 'Barley' 'Khesari' 'Masoor' 'Moong(Green Gram)'
#  'Other Kharif pulses' 'Safflower' 'Sannhamp' 'Sunflower' 'Urad'
#  'Peas & beans (Pulses)' 'other oilseeds' 'Other Cereals' 'Cowpea(Lobia)'
#  'Oilseeds total' 'Guar seed' 'Other Summer Pulses' 'Moth']
# Crop_Year          :  [1997 1998 1999 2000 2001 2002 2003 2004 2005 2006 2007 2008 2009 2010
#  2011 2012 2013 2014 2015 2016 2017 2018 2019 2020]
# Season          :  ['Whole Year ' 'Kharif     ' 'Rabi       ' 'Autumn     ' 'Summer     '
#  'Winter     ']
# ...

# %%
df.head()
# Out:
#            Crop  Crop_Year       Season  State     Area  Production  \
# 0      Arecanut       1997  Whole Year   Assam  73814.0       56708
# 1     Arhar/Tur       1997  Kharif       Assam   6637.0        4685
# 2   Castor seed       1997  Kharif       Assam    796.0          22
# 3      Coconut        1997  Whole Year   Assam  19656.0   126905000
# 4  Cotton(lint)       1997  Kharif       Assam   1739.0         794
#
#    Annual_Rainfall  Fertilizer  Pesticide        Yield
# 0           2051.4  7024878.38   22882.34     0.796087
# 1           2051.4   631643.29    2057.47     0.710435
# 2           2051.4    75755.32     246.76     0.238333
# 3           2051.4  1870661.52    6093.36  5238.051739
# 4           2051.4   165500.63     539.09     0.420909

# %%
df.describe()
# Out:
#           Crop_Year          Area    Production  Annual_Rainfall  \
# count  19689.000000  1.968900e+04  1.968900e+04     19689.000000
# mean    2009.127584  1.799266e+05  1.643594e+07      1437.755177
# std        6.498099  7.328287e+05  2.630568e+08       816.909589
# min     1997.000000  5.000000e-01  0.000000e+00       301.300000
# 25%     2004.000000  1.390000e+03  1.393000e+03       940.700000
# 50%     2010.000000  9.317000e+03  1.380400e+04      1247.600000
# 75%     2015.000000  7.511200e+04  1.227180e+05      1643.700000
# max     2020.000000  5.080810e+07  6.326000e+09      6552.700000
#
#          Fertilizer     Pesticide         Yield
# count  1.968900e+04  1.968900e+04  19689.000000
# mean   2.410331e+07  4.884835e+04     79.954009
# std    9.494600e+07  2.132874e+05    878.306193
# min    5.417000e+01  9.000000e-02      0.000000
# 25%    1.880146e+05  3.567000e+02      0.600000
# 50%    1.234957e+06  2.421900e+03      1.030000
# ...

# %%
df[df.Annual_Rainfall<=940.7].shape    #25
# Out:
# (4971, 10)

# %%
4971/19689
# Out:
# 0.2524760018284321

# %%
df[df.Annual_Rainfall<=1247.6].shape    #50
# Out:
# (9880, 10)

# %%
9880/19689
# Out:
# 0.5018030372289095

# %%
df[df.Annual_Rainfall<=1643.7].shape     #75
# Out:
# (14785, 10)

# %%
14785/19689
# Out:
# 0.7509269135050028

# %%
#iqr = q3-q1
iqr = 1643.7 - 940.7
iqr
# Out:
# 703.0

# %%
#lower = Q1-1.5*iqr
lower = 940.7-1.5*703
lower
# Out:
# -113.79999999999995

# %%
#upper = Q3+1.5*iqr
upper = 1643.7+1.5*703
upper
# Out:
# 2698.2

# %%
outliers = df[(df['Annual_Rainfall'] < lower) | (df['Annual_Rainfall'] > upper)]
outliers
# Out:
#                       Crop  Crop_Year       Season   State      Area  \
# 57                Arecanut       1997  Whole Year   Kerala   76145.0
# 58            Black pepper       1997  Whole Year   Kerala  173855.0
# 59               Cashewnut       1997  Whole Year   Kerala   96073.0
# 60                Coconut        1997  Whole Year   Kerala  884344.0
# 61                 Tapioca       1997  Whole Year   Kerala  132875.0
# ...                    ...        ...          ...     ...       ...
# 19505  Other Kharif pulses       2012  Kharif          Goa     226.0
# 19506                 Ragi       2012  Kharif          Goa      48.0
# 19507                 Rice       2012  Kharif          Goa   31255.0
# 19508                 Rice       2012  Rabi            Goa   14575.0
# 19509            Sugarcane       2012  Whole Year      Goa     854.0
#
#        Production  Annual_Rainfall   Fertilizer  Pesticide        Yield
# ...

# %%
sns.boxplot(x=df['Annual_Rainfall'])
# Out:
# <Axes: xlabel='Annual_Rainfall'>

# %%
sns.histplot(df['Annual_Rainfall'],bins=10)
# Out:
# <Axes: xlabel='Annual_Rainfall', ylabel='Count'>

# %%
df.dtypes
# Out:
# Crop                object
# Crop_Year            int64
# Season              object
# State               object
# Area               float64
# Production           int64
# Annual_Rainfall    float64
# Fertilizer         float64
# Pesticide          float64
# Yield              float64
# dtype: object

# %%
df.Season.value_counts()
# Out:
# Kharif         8232
# Rabi           5742
# Whole Year     3717
# Summer         1195
# Autumn          414
# Winter          389
# Name: Season, dtype: int64

# %%
plt.figure(figsize=(10,10))
df.Season.value_counts().plot.bar()
plt.ylabel('Rate of crops grown')
plt.xlabel('Season')
plt.title('crops grown in different season')
plt.legend()
plt.show()

# %%
plt.scatter(df.Annual_Rainfall,df.Production)
plt.show()

# %%
df.isnull().sum()
# Out:
# Crop               0
# Crop_Year          0
# Season             0
# State              0
# Area               0
# Production         0
# Annual_Rainfall    0
# Fertilizer         0
# Pesticide          0
# Yield              0
# dtype: int64

# %%
crop_counts = df['Crop'].value_counts()
print(crop_counts)
# Out:
# Rice                     1197
# Maize                     975
# Moong(Green Gram)         740
# Urad                      733
# Groundnut                 725
# Sesamum                   685
# Potato                    628
# Sugarcane                 605
# Wheat                     545
# Rapeseed &Mustard         528
# Bajra                     524
# Jowar                     513
# Arhar/Tur                 508
# Ragi                      498
# Gram                      490
# Small millets             485
# Cotton(lint)              476
# Onion                     454
# Sunflower                 441
# Dry chillies              419
# Other Kharif pulses       382
# Horse-gram                371
# Peas & beans (Pulses)     369
# Tobacco                   364
# Other  Rabi pulses        355
# Soyabean                  349
# Turmeric                  337
# Masoor                    324
# Ginger                    323
# Linseed                   308
# Castor seed               300
# ...

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='Crop')
plt.xticks(rotation=90)
plt.title('Crop Distribution')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['Area'], bins=20, edgecolor='k')
plt.title('Distribution of Area')
plt.xlabel('Area')
plt.ylabel('Frequency')
plt.show()

# %%
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_7228\3169171290.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()

# %%
df["Yield"] = np.where(df["Crop"] == "Coconut", 0.234545, df["Yield"])

# %%
df.head()
# Out:
#            Crop  Crop_Year       Season  State     Area  Production  \
# 0      Arecanut       1997  Whole Year   Assam  73814.0       56708
# 1     Arhar/Tur       1997  Kharif       Assam   6637.0        4685
# 2   Castor seed       1997  Kharif       Assam    796.0          22
# 3      Coconut        1997  Whole Year   Assam  19656.0   126905000
# 4  Cotton(lint)       1997  Kharif       Assam   1739.0         794
#
#    Annual_Rainfall  Fertilizer  Pesticide        Yield
# 0           2051.4  7024878.38   22882.34     0.796087
# 1           2051.4   631643.29    2057.47     0.710435
# 2           2051.4    75755.32     246.76     0.238333
# 3           2051.4  1870661.52    6093.36  5238.051739
# 4           2051.4   165500.63     539.09     0.420909

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=df, x='Crop_Year', y='Production')
plt.title('Crop Year vs. Production')
plt.xlabel('Crop Year')
plt.ylabel('Production')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.violinplot(data=df, x='Crop', y='Yield')
plt.xticks(rotation=90)
plt.title('Violin Plot of Yield by Crop')
plt.xlabel('Crop')
plt.ylabel('Yield')
plt.show()

# %%
correlation_matrix = df.corr()


plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_7228\3910169572.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()

# %%
scatter_matrix = pd.plotting.scatter_matrix(df, figsize=(12, 12), diagonal='hist')
plt.suptitle('Scatter Plot Matrix')
plt.show()

# %%
plt.figure(figsize=(20,10))
df.groupby('Crop').size().plot(kind = 'bar', )
plt.show()

# %%
plt.figure(figsize=(30,20))
df.groupby('Crop').size().plot(kind = 'pie', )
plt.show()

# %% [markdown]
# # CA 1 Question Answers

# %% [markdown]
# 1. What is the most common crop in the dataset?

# %%
most_common_crop = df['Crop'].mode()[0]
print("The most common crop in the dataset is:", most_common_crop)
# Out:
# The most common crop in the dataset is: Rice

# %% [markdown]
# 2. Which year had the highest crop production?

# %%
year_with_highest_production = df[df['Production'] == df['Production'].max()]['Crop_Year'].values[0]

print("The year with the highest crop production is:", year_with_highest_production)
# Out:
# The year with the highest crop production is: 2005

# %% [markdown]
# 3. What is the distribution of different seasons in the dataset?

# %%
season_distribution = df['Season'].value_counts()


print("Distribution of Seasons:")
print(season_distribution)
# Out:
# Distribution of Seasons:
# Kharif         8232
# Rabi           5742
# Whole Year     3717
# Summer         1195
# Autumn          414
# Winter          389
# Name: Season, dtype: int64

# %% [markdown]
# 4. Does the choice of crop season impact crop production?

# %%
season_production = df.groupby('Season')['Production'].mean()

print("Average Production by Season:")
print(season_production)
# Out:
# Average Production by Season:
# Season
# Autumn         2.038808e+05
# Kharif         6.562785e+05
# Rabi           4.941428e+05
# Summer         2.039591e+05
# Whole Year     8.459853e+07
# Winter         1.507732e+06
# Name: Production, dtype: float64

# %% [markdown]
# 5. What is the range of annual rainfall in the dataset?

# %%
min_rainfall = df['Annual_Rainfall'].min()
max_rainfall = df['Annual_Rainfall'].max()

rainfall_range = max_rainfall - min_rainfall

print("Range of Annual Rainfall:", rainfall_range)
# Out:
# Range of Annual Rainfall: 6251.4

# %% [markdown]
# 6. How many unique fertilizer types are present in the dataset?

# %%
unique_fertilizer_count = df['Fertilizer'].nunique()


print("Number of Unique Fertilizer Types:", unique_fertilizer_count)
# Out:
# Number of Unique Fertilizer Types: 18598

# %% [markdown]
# 7. What is the most commonly used pesticide

# %%
pesticide_counts = df['Pesticide'].value_counts()


most_common_pesticide = pesticide_counts.index[0]


print("Most Commonly Used Pesticide:", most_common_pesticide)
# Out:
# Most Commonly Used Pesticide: 0.99

# %% [markdown]
# 8. What is the distribution of crop yields?

# %%
yield_stats = df['Yield'].describe()


plt.figure(figsize=(10, 6))
plt.hist(df['Yield'], bins=20, edgecolor='k')
plt.title('Distribution of Crop Yields')
plt.xlabel('Yield')
plt.ylabel('Frequency')
plt.grid(True)

print("Summary Statistics for Crop Yields:")
print(yield_stats)

plt.show()
# Out:
# Summary Statistics for Crop Yields:
# count    19689.000000
# mean        79.954009
# std        878.306193
# min          0.000000
# 25%          0.600000
# 50%          1.030000
# 75%          2.388889
# max      21105.000000
# Name: Yield, dtype: float64

# %% [markdown]
# 9. Is there a correlation between annual rainfall and crop production?

# %%
correlation = df['Annual_Rainfall'].corr(df['Production'])


if correlation > 0:
    correlation_result = "There is a positive correlation."
elif correlation < 0:
    correlation_result = "There is a negative correlation."
else:
    correlation_result = "There is no correlation."


print("Correlation Coefficient:", correlation)
print("Correlation Result:", correlation_result)
# Out:
# Correlation Coefficient: 0.02987939123307232
# Correlation Result: There is a positive correlation.

# %% [markdown]
# 10. Does the choice of crop season impact crop production?

# %%
season_production = df.groupby('Season')['Production'].mean().sort_values()


print("Average Production by Season:")
print(season_production)
# Out:
# Average Production by Season:
# Season
# Autumn         2.038808e+05
# Summer         2.039591e+05
# Rabi           4.941428e+05
# Kharif         6.562785e+05
# Winter         1.507732e+06
# Whole Year     8.459853e+07
# Name: Production, dtype: float64

# %% [markdown]
# 11. Is there a relationship between crop area and pesticide use?

# %%
correlation = df['Area'].corr(df['Pesticide'])

if correlation > 0:
    relationship_result = "There is a positive relationship."
elif correlation < 0:
    relationship_result = "There is a negative relationship."
else:
    relationship_result = "There is no relationship."


print("Correlation Coefficient between Area and Pesticide:", correlation)
print("Relationship Result:", relationship_result)
# Out:
# Correlation Coefficient between Area and Pesticide: 0.9734785648520126
# Relationship Result: There is a positive relationship.

# %% [markdown]
# 12. How does crop yield vary with different types of crops?

# %%
crop_yield = df.groupby('Crop')['Yield'].mean().sort_values()


plt.figure(figsize=(12, 6))
crop_yield.plot(kind='bar', color='green')
plt.title('Average Crop Yield by Crop Type')
plt.xlabel('Crop Type')
plt.ylabel('Average Yield')
plt.xticks(rotation=90)
plt.grid(axis='y', linestyle='--', alpha=0.7)


plt.show()

# %% [markdown]
# 13. Are there any noticeable trends in crop production over the years?

# %%
yearly_production = df.groupby('Crop_Year')['Production'].sum()


plt.figure(figsize=(12, 6))
yearly_production.plot(marker='o', linestyle='-', color='blue')
plt.title('Crop Production Over the Years')
plt.xlabel('Crop Year')
plt.ylabel('Total Production')
plt.grid(True)


plt.show()

# %% [markdown]
# 14. What is the relationship between fertilizer and pesticide usage?

# %%
correlation = df['Fertilizer'].corr(df['Pesticide'])


if correlation > 0:
    relationship_result = "There is a positive relationship."
elif correlation < 0:
    relationship_result = "There is a negative relationship."
else:
    relationship_result = "There is no relationship."


print("Correlation Coefficient between Fertilizer and Pesticide:", correlation)
print("Relationship Result:", relationship_result)
# Out:
# Correlation Coefficient between Fertilizer and Pesticide: 0.9549914691582144
# Relationship Result: There is a positive relationship.

# %% [markdown]
# 15. What is the distribution of crop production across different states

# %%
state_production = df.groupby('State')['Production'].sum().sort_values(ascending=False)

plt.figure(figsize=(12, 6))
state_production.plot(kind='bar', color='purple')
plt.title('Crop Production Across States')
plt.xlabel('State')
plt.ylabel('Total Production')
plt.xticks(rotation=90)
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %% [markdown]
# 16.Do certain states or regions consistently outperform others in terms of crop production?

# %%
production_stats = df.groupby('State')['Production'].describe()
print(production_stats)
# Out:
#                     count          mean           std    min       25%  \
# State
# Andhra Pradesh     1266.0  2.059733e+07  1.641643e+08    0.0   6000.00
# Arunachal Pradesh   292.0  3.260962e+04  4.677178e+04  202.0   2644.50
# Assam               731.0  4.976354e+06  2.700595e+07   22.0   5134.50
# Bihar               896.0  6.082071e+05  1.831099e+06   19.0   3494.25
# Chhattisgarh        915.0  1.563897e+05  8.869457e+05    0.0   1008.00
# Delhi               203.0  1.313311e+04  2.688353e+04    1.0    182.00
# Goa                 246.0  8.918692e+06  3.283008e+07    0.0    498.25
# Gujarat             817.0  9.884721e+05  2.465953e+06  161.0  32300.00
# Haryana             631.0  9.346112e+05  2.459336e+06    0.0   1295.00
# Himachal Pradesh    616.0  5.243044e+04  1.505382e+05    0.0    143.75
# Jammu and Kashmir   631.0  4.801645e+04  1.444076e+05    0.0     40.00
# Jharkhand           270.0  1.621994e+05  4.430510e+05   26.0  11302.25
# ...

# %%
plt.figure(figsize=(12, 6))
production_stats['mean'].plot(kind='bar', color='orange')
plt.title('Average Crop Production by State')
plt.xlabel('State')
plt.ylabel('Average Production')
plt.xticks(rotation=90)
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %% [markdown]
# 17.What is the total production of all crops combined for each year?

# %%
yearly_total_production = df.groupby('Crop_Year')['Production'].sum()

print("Total Production for Each Year:")
print(yearly_total_production)
# Out:
# Total Production for Each Year:
# Crop_Year
# 1997     6087009873
# 1998     7868086697
# 1999     8550025528
# 2000     9562470060
# 2001     9314563490
# 2002    12409349456
# 2003    12313711969
# 2004    13817065380
# 2005    14951210018
# 2006    15702675600
# 2007    14471191552
# 2008    16165771744
# 2009    16604163998
# 2010    11952654246
# 2011    19260119964
# 2012    13030757834
# 2013    17040254359
# 2014    17729042495
# 2015    18329298670
# 2016    16357287264
# 2017    15873843241
# 2018    17933914698
# 2019    18272602364
# 2020       10177226
# Name: Production, dtype: int64

# %% [markdown]
# 18.Do different regions or states have distinct preferences for specific crop types?

# %%
region_crop_counts = df.groupby(['State', 'Crop'])['Crop'].count().unstack().fillna(0)


print(region_crop_counts)
# Out:
# Crop               Arecanut  Arhar/Tur  Bajra  Banana  Barley  Black pepper  \
# State
# Andhra Pradesh         18.0       41.0   45.0    18.0     0.0           2.0
# Arunachal Pradesh       0.0        4.0    0.0     0.0     0.0           0.0
# Assam                  22.0       23.0    0.0    21.0     0.0          13.0
# Bihar                   0.0       23.0   23.0    10.0    22.0           0.0
# Chhattisgarh            0.0       20.0   39.0     0.0    20.0           0.0
# Delhi                   0.0        4.0   22.0     0.0    22.0           0.0
# Goa                    13.0        0.0    0.0    13.0     0.0          17.0
# Gujarat                 0.0       23.0   46.0    22.0     0.0           0.0
# Haryana                 0.0       22.0   23.0     2.0    23.0           0.0
# Himachal Pradesh        0.0       20.0   20.0     0.0    22.0           0.0
# Jammu and Kashmir       0.0        2.0   24.0     0.0    35.0           0.0
# ...

# %%
plt.figure(figsize=(30, 16))
region_crop_counts.plot(kind='bar', stacked=True)
plt.title('Crop Type Distribution by State/Region')
plt.xlabel('State/Region')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.legend(title='Crop Type', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()

# %% [markdown]
# 19.What is the most common crop season across all states or regions?

# %%
common_season = df['Season'].mode()[0]

print("Most Common Crop Season:", common_season)
# Out:
# Most Common Crop Season: Kharif

# %% [markdown]
# 20.What is the total production of Sugercane across all states or regions for each year? answer

# %%
Sugarcane = 'Sugarcane'

crop_data = df[df['Crop'] == Sugarcane]


yearly_production = crop_data.groupby('Crop_Year')['Production'].sum()


print("Total Production of", Sugarcane, "by Year:")
print(yearly_production)
# Out:
# Total Production of Sugarcane by Year:
# Crop_Year
# 1997    200252854
# 1998    265785548
# 1999    300247251
# 2000    295532743
# 2001    296059757
# 2002    286598917
# 2003    239439088
# 2004    229509730
# 2005    285153532
# 2006    334295217
# 2007    341020241
# 2008    280460500
# 2009    287891757
# 2010    336435675
# 2011    345737808
# 2012    339456205
# 2013    366406990
# 2014    382749767
# 2015    339587198
# 2016    321058140
# 2017    383894380
# 2018    404122015
# 2019    366871143
# 2020      7970299
# Name: Production, dtype: int64

# %%
data = df['Area']

num_bins = 20 

plt.hist(data, bins=num_bins, edgecolor='k')
plt.xlabel('Area')
plt.ylabel('Frequency')
plt.title('Histogram of Area')
plt.grid(True)
plt.show()
